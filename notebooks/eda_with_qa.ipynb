# %% [markdown]
# ## EDA

# %% [markdown]
# - Vectorizes severity raster to polygons
# - Dissolves by class
# - Calculates areas
# - Plots map
# - Overlays with land use for summaries.

# %% [markdown]
# **Libraries**

# %%
import os
import rasterio
from rasterio import features
import geopandas as gpd
from shapely.geometry import shape
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %% [markdown]
# **Paths**

# %%
BASE_DIR = os.path.abspath(os.path.join(os.getcwd(), '..'))
DATA_DIR = os.path.join(BASE_DIR, 'data')
OUTPUT_DIR = os.path.join(BASE_DIR, r'output\with_qa')
os.makedirs(OUTPUT_DIR, exist_ok=True)

SEVERITY_PATH = os.path.join(OUTPUT_DIR, 'severity_qa.tif')
POLYGONS_PATH = os.path.join(OUTPUT_DIR, 'burn_severity_polygons_qa.gpkg')
LANDUSE_PATH = os.path.join(DATA_DIR, 'landuse_aoi.geojson')


with rasterio.open(SEVERITY_PATH) as src:
    severity = src.read(1)
    transform = src.transform
    crs = src.crs
    nodata = src.nodata

# %% [markdown]
# **1. Convert raster to polygons**

# %%
records = []

for geom, value in features.shapes(
        severity,
        mask=severity != nodata,
        transform=transform):

    records.append({
        "geometry": shape(geom),
        "severity": int(value)
    })

gdf = gpd.GeoDataFrame(records, crs=crs)

# %% [markdown]
# **2. Disolve by severity class (clean perimeters)**

# %%
#One polygon per severity class instead of many pixels

gdf_dissolved = gdf.dissolve(by="severity", as_index=False)

# %% [markdown]
# **3.A. Area Compromised per severity class**

# %%
#Because Sentinel-2 UTM CRS is in meters, area is reliable
gdf_dissolved["area_m2"] = gdf_dissolved.geometry.area
gdf_dissolved["area_ha"] = gdf_dissolved["area_m2"] / 10_000
gdf_dissolved["area_km2"] = gdf_dissolved["area_m2"] / 1_000_000

# %%
#Add severity labels (readable output)
severity_labels = {
    0: "Unburned",
    1: "Low",
    2: "Moderate-Low",
    3: "Moderate-High",
    4: "High"
}

gdf_dissolved["severity_label"] = gdf_dissolved["severity"].map(severity_labels)

# %%
#Save vector output
gdf_dissolved.to_file(POLYGONS_PATH, driver="GPKG")

# %%
# Color map for severity classes
colors = {
    0: "#ffffff",   # Unburned – white
    1: "#ffffb2",   # Low – light yellow
    2: "#fecc5c",   # Moderate-Low – yellow-orange
    3: "#fd8d3c",   # Moderate-High – orange
    4: "#e31a1c",   # High – red
}

# Map severity column to colors
gdf_dissolved["color"] = gdf_dissolved["severity"].map(colors)

# Plot
fig, ax = plt.subplots(figsize=(10, 10))
gdf_dissolved.plot(
    ax=ax,
    color=gdf_dissolved["color"],
    edgecolor="black",
    linewidth=0.5
)

ax.set_title("Burn Severity – 01/08/2025 to 23/08/2025", fontsize=16)
ax.axis("off")

# Optional legend

legend_patches = [
    mpatches.Patch(color=v, label=k) for k, v in zip(
        gdf_dissolved["severity_label"], gdf_dissolved["color"]
    )
]
ax.legend(handles=legend_patches, loc="lower left")

plt.show()

# %%
area_table = (
    gdf_dissolved[["severity", "severity_label", "area_ha"]]
    .sort_values("severity")
)

print(area_table)
# Out:
#    severity severity_label   area_ha
# 0         0       Unburned  37686.64
# 1         1            Low   5713.12
# 2         2   Moderate-Low  15335.92
# 3         3  Moderate-High  14672.48
# 4         4           High    729.12

# %%
area_table.to_csv(
    os.path.join(OUTPUT_DIR, "burn_severity_area_summary_qa.csv"),
    index=False
)

# %% [markdown]
# **3.B Land Use Damaged per severity class**

# %%
landuse = gpd.read_file(LANDUSE_PATH)
burn = gpd.read_file(POLYGONS_PATH)

print(burn.columns)
print(landuse.columns)

print(burn.crs)
print(landuse.crs)
# Out:
# Index(['severity', 'area_m2', 'area_ha', 'area_km2', 'severity_label',
#        'geometry'],
#       dtype='object')
# Index(['obj_type', 'name', 'info', 'damage_gra', 'det_method', 'notation',
#        'or_src_id', 'dmg_src_id', 'cd_value', 'geometry'],
#       dtype='object')
# EPSG:32629
# EPSG:32629

# %%
overlay = gpd.overlay(
    burn,
    landuse,
    how="intersection"
)

# %%
overlay["area_ha"] = overlay.geometry.area / 10_000

# %%
summary = (
    overlay
    .groupby(["severity_label", "info"])["area_ha"]
    .sum()
    .reset_index()
)

print(summary)
# Out:
#    severity_label                                               info  \
# 0            High              222-Fruit trees and berry plantations
# 1            High                   242-Complex cultivation patterns
# 2            High  243-Land principally occupied by agriculture, ...
# 3            High                            311-Broad-leaved forest
# 4            High                              312-Coniferous forest
# 5            High                                   313-Mixed forest
# 6            High                              321-Natural grassland
# 7            High                            322-Moors and heathland
# 8            High                    324-Transitional woodland shrub
# 9            High                       333-Sparsely vegetated areas
# 10           High                                    334-Burnt areas
# 11           High                                          998-Other
# 12            Low              222-Fruit trees and berry plantations
# 13            Low                   242-Complex cultivation patterns
# 14            Low  243-Land principally occupied by agriculture, ...
# 15            Low                            311-Broad-leaved forest
# 16            Low                              312-Coniferous forest
# 17            Low                                   313-Mixed forest
# 18            Low                              321-Natural grassland
# 19            Low                            322-Moors and heathland
# 20            Low                    324-Transitional woodland shrub
# 21            Low                       333-Sparsely vegetated areas
# 22            Low                                    334-Burnt areas
# 23            Low                                          998-Other
# 24  Moderate-High              222-Fruit trees and berry plantations
# 25  Moderate-High                   242-Complex cultivation patterns
# 26  Moderate-High  243-Land principally occupied by agriculture, ...
# 27  Moderate-High                            311-Broad-leaved forest
# 28  Moderate-High                              312-Coniferous forest
# 29  Moderate-High                                   313-Mixed forest
# 30  Moderate-High                              321-Natural grassland
# 31  Moderate-High                            322-Moors and heathland
# 32  Moderate-High                    324-Transitional woodland shrub
# 33  Moderate-High                       333-Sparsely vegetated areas
# 34  Moderate-High                                    334-Burnt areas
# 35  Moderate-High                                          998-Other
# 36   Moderate-Low              222-Fruit trees and berry plantations
# 37   Moderate-Low                   242-Complex cultivation patterns
# 38   Moderate-Low  243-Land principally occupied by agriculture, ...
# 39   Moderate-Low                            311-Broad-leaved forest
# 40   Moderate-Low                              312-Coniferous forest
# 41   Moderate-Low                                   313-Mixed forest
# 42   Moderate-Low                              321-Natural grassland
# 43   Moderate-Low                            322-Moors and heathland
# 44   Moderate-Low                    324-Transitional woodland shrub
# 45   Moderate-Low                       333-Sparsely vegetated areas
# 46   Moderate-Low                                    334-Burnt areas
# 47   Moderate-Low                                          998-Other
# 48       Unburned              222-Fruit trees and berry plantations
# 49       Unburned                   242-Complex cultivation patterns
# 50       Unburned  243-Land principally occupied by agriculture, ...
# 51       Unburned                            311-Broad-leaved forest
# 52       Unburned                              312-Coniferous forest
# 53       Unburned                                   313-Mixed forest
# 54       Unburned                              321-Natural grassland
# 55       Unburned                            322-Moors and heathland
# 56       Unburned                    324-Transitional woodland shrub
# 57       Unburned                       333-Sparsely vegetated areas
# 58       Unburned                                    334-Burnt areas
# 59       Unburned                                          998-Other
#
#         area_ha
# 0      0.330964
# 1      8.298984
# 2     18.122175
# 3    179.237972
# 4     71.609262
# 5      6.489952
# 6     12.437894
# 7    295.698969
# 8    133.955388
# 9      1.095293
# 10     0.040000
# 11     0.000443
# 12     6.125654
# 13    63.798180
# 14    94.839299
# 15   263.197738
# 16   392.162711
# 17    96.530828
# 18    92.522786
# 19  1571.535929
# 20   191.443646
# 21    71.567574
# 22     2.428779
# 23    63.427211
# 24    39.289104
# 25   174.208698
# 26   333.034035
# 27  1492.443958
# 28  1531.980118
# 29   354.773559
# 30   420.801115
# 31  8251.675413
# 32  1858.036184
# 33    53.519444
# 34    13.648185
# 35    13.832212
# 36    40.914302
# 37   170.136378
# 38   359.391411
# 39  1024.254745
# 40  1121.868084
# 41   382.795584
# 42   636.633316
# 43  9526.593310
# 44  1008.481896
# 45   227.603567
# 46    18.384405
# 47    53.888773
# 48     0.170707
# 49     8.764983
# 50    16.664461
# 51    17.864926
# 52     8.663407
# 53     4.476826
# 54    13.172883
# 55    88.662016
# 56    13.216133
# 57     0.688014
# 58     0.208829
# 59    78.385069

# %%
top3 = (
    summary
    .groupby("severity_label", group_keys=False)
    .apply(lambda x: x.nlargest(3, "area_ha"))
    .reset_index(drop=True)
)

print(top3)
# Out:
#    severity_label                             info      area_ha
# 0            High          322-Moors and heathland   295.698969
# 1            High          311-Broad-leaved forest   179.237972
# 2            High  324-Transitional woodland shrub   133.955388
# 3             Low          322-Moors and heathland  1571.535929
# 4             Low            312-Coniferous forest   392.162711
# 5             Low          311-Broad-leaved forest   263.197738
# 6   Moderate-High          322-Moors and heathland  8251.675413
# 7   Moderate-High  324-Transitional woodland shrub  1858.036184
# 8   Moderate-High            312-Coniferous forest  1531.980118
# 9    Moderate-Low          322-Moors and heathland  9526.593310
# 10   Moderate-Low            312-Coniferous forest  1121.868084
# 11   Moderate-Low          311-Broad-leaved forest  1024.254745
# 12       Unburned          322-Moors and heathland    88.662016
# 13       Unburned                        998-Other    78.385069
# 14       Unburned          311-Broad-leaved forest    17.864926
# C:\Users\User\AppData\Local\Temp\ipykernel_12384\1352987368.py:4: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.nlargest(3, "area_ha"))

# %%
top3.to_csv(
    os.path.join(OUTPUT_DIR, "top_3_landuse_qa.csv"),
    index=False
)
